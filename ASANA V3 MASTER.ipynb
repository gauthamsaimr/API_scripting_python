# %% [markdown]
# ### Asana1

# %%
import feather
import pandas as pd
from pandas import DataFrame
import numpy as np
import json
import requests
filename="asana111.csv"
url = "https://app.asana.com/api/1.0/projects/926982266304264/tasks"
payload = "undefined="
headers = {
    'Content-Type': "application/x-www-form-urlencoded",
    'Authorization': "Bearer 0/2c2fb14794fb8e35b5aa8c5fa6209ba0",
    'cache-control': "no-cache",
    'Postman-Token': "18728ed1-8885-4d5f-be50-c39ce3b6b053"
    }
response = requests.request("GET", url, data=payload, headers=headers)
list1= response.text.encode('utf8')
list2=pd.read_json(list1)
## Normalize to split the Json to DataFrame
from pandas.io.json import json_normalize 
dfa1=pd.io.json.json_normalize(list2.data)
# Drop the unwanted columns
dfa1=dfa1.drop(columns=['resource_type'])
#pd.set_option('display.max_rows', dfa1.shape[0]+1)
#dfa1['name'].where(dfa1['name'] == 'The Car Park')
dfaGID=dfa1.gid
listGID=list(dfaGID)

### Asana 2
#Get the fist extended to the url from list
base_url = "https://app.asana.com/api/1.0/tasks/"
url = base_url + listGID[0]
payload = "undefined="
headers = {
    'Content-Type': "application/x-www-form-urlencoded",
    'Authorization': "Bearer 0/2c2fb14794fb8e35b5aa8c5fa6209ba0",
    'cache-control': "no-cache",
    'Postman-Token': "f0ef4da4-d89b-48a0-94bf-7ab96483d783"
}
response = requests.request("GET", url, data=payload, headers=headers)
a1= response.text.encode('utf8')
a2=pd.read_json(a1)
# Normalize and get the given gid of the list parsed to the url
from pandas.io.json import json_normalize 
a2.data.gid
#aa1=pd.io.json.json_normalize(a2.data.assignee)
### GID
#aaGID=aa1[['gid']]
#aaGID
gid=a2.data.gid
aa2=pd.io.json.json_normalize(a2.data.custom_fields)
aa22=aa2[['name','text_value','number_value']]
aaDate=aa22.loc[[1]]
aaDate=aaDate.drop(columns=['number_value'])
### Date
date=aaDate.text_value[1]
aaPhones=aa22.iloc[6:10]
aaPhones=aaPhones.drop(columns=['text_value'])
### Phones carriers dataframe
new_row = {'name':'ShipDate', 'number_value': date }
aaPhones= aaPhones.append(new_row, ignore_index=True)
## insert a new column to dataframe 
aaPhones.insert(2, "gid",0)
#replace it with the gid
aaPhones['gid']=aaPhones.gid.replace(0,gid)
dfg=pd.merge(aaPhones,dfa1,on='gid')
dfg.rename(columns={'name_x':'carrier','name_y':'Location'}, inplace=True)
dfg = dfg[['Location','carrier','number_value','gid']]
dfg.to_csv(filename,index=False,mode='a')
# repeat the process for all the gid's given in the list
for i in range(1,len(listGID)):
    base_url = "https://app.asana.com/api/1.0/tasks/"
    url = base_url + listGID[i]
    payload = "undefined="
    headers = {
        'Content-Type': "application/x-www-form-urlencoded",
        'Authorization': "Bearer 0/2c2fb14794fb8e35b5aa8c5fa6209ba0",
        'cache-control': "no-cache",
        'Postman-Token': "f0ef4da4-d89b-48a0-94bf-7ab96483d783"
    }
    response = requests.request("GET", url, data=payload, headers=headers)
    a1= response.text.encode('utf8')
    a2=pd.read_json(a1)
    from pandas.io.json import json_normalize 
    a2.data.gid
    #aa1=pd.io.json.json_normalize(a2.data.assignee)
    ### GID
    #aaGID=aa1[['gid']]
    #aaGID
    gid=a2.data.gid
    aa2=pd.io.json.json_normalize(a2.data.custom_fields)
    aa22=aa2[['name','text_value','number_value']]
    aaDate=aa22.loc[[1]]
    aaDate=aaDate.drop(columns=['number_value'])
    ### Date
    date=aaDate.text_value[1]
    aaPhones=aa22.iloc[6:10]
    aaPhones=aaPhones.drop(columns=['text_value'])
    ### Phones
    new_row = {'name':'ShipDate', 'number_value': date }
    aaPhones= aaPhones.append(new_row, ignore_index=True)
    aaPhones.insert(2, "gid",0)
    aaPhones['gid']=aaPhones.gid.replace(0,gid)
    dfg=pd.merge(aaPhones,dfa1,on='gid')
    dfg.rename(columns={'name_x':'carrier','name_y':'Location'}, inplace=True)
    dfg = dfg[['Location','carrier','number_value','gid']]
    #The code below appends to the same csv file everytime in the loop so that we have one single csv at the end
    dfg.to_csv(filename,index=False, header=False ,mode='a')

data = pd.read_csv(filename)
df1=DataFrame(data,columns=['Location','carrier','number_value'])
#df1['number_value'].replace('', np.nan, inplace=True)
df1=df1.fillna(0)
df2=pd.DataFrame(df1)
pivot = pd.pivot_table(df2,index=['Location'],columns=['carrier'],values=['number_value'] , aggfunc='min')
print(pivot)
# Out:
# carrier                                                         Printers  \
# Location
# 49ers                                              number_value        0
# Ak-Chin Pavilion Pavilion                          number_value        0
# Alameda County Fairgrounds Seasonal Return         number_value        0
# Aloha Stadium Test Drive Return                    number_value        0
# Alpine Valley Music Theatre                        number_value        0
# Ameris Bank Amphitheater @ Encore Park             number_value        0
# Angels Weekend Rental                              number_value        0
# Arizona State - 15 Units & Printers                number_value        0
# Arizona State University                           number_value       25
# Asana Tutorial                                     number_value        0
# Ascend Amphitheater                                number_value        0
# BB&T Pavilion                                      number_value        0
# BBT Center Phones                                  number_value        0
# BBT Center Phones in Meraki                        number_value        0
# Bank of New Hampshire Pavilion                     number_value        0
# Bayfront Park Amphitheater                         number_value        0
# Baylor University                                  number_value        0
# Bear Mountain Swap                                 number_value        0
# Blossom Music Center                               number_value        0
# Brewers                                            number_value        0
# Broncos Carrier Swap                               number_value        0
# Broncos Return                                     number_value        0
# CNG Rental                                         number_value        0
# CNG Rental Return                                  number_value        0
# COTA                                               number_value        0
# COTA Device Swap                                   number_value        0
# CU Boulder                                         number_value        0
# CU Boulder - 23 Units & Printers                   number_value        0
# CU Boulder iPhone Swap                             number_value        0
# CUBS Missing Units                                 number_value        0
# Cal Berkeley                                       number_value        0
# Cal poly Swap                                      number_value        0
# Cellairis Amphitheater @ Lakewood                  number_value        0
# Charlotte Metro Credit Union Amphitheatre          number_value        0
# Chicago Cubs                                       number_value        0
# Chicago White Sox                                  number_value        0
# Cleveland Swap                                     number_value        0
# Coastal Credit Union Music Park @ Walnut Creek     number_value        0
# Colorado Rockies                                   number_value        0
# Concord Pavilion                                   number_value        0
# Coral Sky Amphitheatre                             number_value        0
# Coral Sky Rental                                   number_value        0
# Coral Sky Rental Return                            number_value        0
# Cornerstone Seasonal Return                        number_value        0
# Cubs Rental                                        number_value        2
# Darien Lake Performing Arts Center                 number_value        0
# Denver Broncos                                     number_value       30
# Denver Broncos - 30 Units & Printers               number_value        0
# Dos XX Pavilion                                    number_value        0
# FITT                                               number_value        5
# Farm Bureau Insurance Lawn @ White River State ... number_value        0
# FedEx Field Rental                                 number_value       15
# Five Point Amphitheater                            number_value        0
# Florida State Test Drive Return                    number_value        0
# Ford Amphitheatre @ Coney Island Boardwalk         number_value        0
# Frisco Rough Riders Baseball Return                number_value        8
# GA Tech                                            number_value        0
# GA Tech/Lanier - 42 Units & Printers               number_value        0
# Georgia Southern                                   number_value        0
# Gillette/Patriots                                  number_value       39
# Glen Helen Amphitheater                            number_value        0
# Greek Theater                                      number_value       15
# Hollywood Bowl                                     number_value        0
# Hollywood Casino Amp - Chicago                     number_value        0
# Hollywood Casino Amp - St. Louis                   number_value        0
# Huntington Bank Pavilion at Northerly Island       number_value        0
# Interstate MN                                      number_value      NaN
# Interstate Test Drive Return                       number_value        0
# Interstate WI                                      number_value        0
# Iowa State University                              number_value        0
# Iowa test drive                                    number_value        0
# Isleta Amphitheater                                number_value        0
# Jiffy Lube Live                                    number_value        0
# Joe's Auto Park Device Swap                        number_value        0
# Joe's Auto Swap Return - 4 Units                   number_value        0
# Kaboo Del Mar                                      number_value        0
# KeyBank Pavilion                                   number_value        0
# Kroenke Equipment Swap                             number_value        0
# Kroenke Week Rental                                number_value        0
# LA Angels Rental                                   number_value      NaN
# LA Angels Rental Return                            number_value        0
# LAFC Suitcase Return                               number_value        0
# LSU                                                number_value        0
# LSU - 75 Units & Printers                          number_value        0
# LSU Baseball Return                                number_value        0
# Lakeview Amphitheater                              number_value        0
# Lanier Orlando Swap                                number_value        0
# Las Vegas NYE REEF Parking Rental                  number_value        6
# Levi's Rental Return                               number_value        0
# MUFC Seasonal Return                               number_value        0
# Mann Center                                        number_value        0
# Mclaurin Baseball Return                           number_value        0
# Mclaurin Device Swap                               number_value        0
# Mid-Florida Credit Union Amphitheatre              number_value        0
# Mississippi State                                  number_value        0
# Mississippi State Return                           number_value        0
# Mississippi State University                       number_value       13
# Mississippi State University - 63 Units & 13 Pr... number_value        0
# Mississippi State University Baseball Return       number_value        0
# Montage Mountain (formerly Toyota)                 number_value        0
# NYRA Swap Part 1                                   number_value        0
# NYRA Swap Part 2                                   number_value        0
# NYSP Green Lakes                                   number_value        0
# NYSP Jones Beach                                   number_value        0
# NYSP Robert Moses                                  number_value        0
# NYSP Sunken Meadow                                 number_value        0
# Newpoint iPhone Swap                               number_value        0
# North Island Credit Union Amphitheatre             number_value        0
# Notre Dame                                         number_value        0
# Notre Dame - 40 Units & Printers                   number_value        0
# Oak Mountain Amphitheater                          number_value        0
# Oakland A's Return                                 number_value        0
# Oklahoma State                                     number_value        0
# Oklahoma State - 30 Units                          number_value        0
# P.N.C. Bank Arts Center - 5 units                  number_value        0
# P.N.C. Bank Arts Center - 6 units                  number_value        0
# PGA Return- 20 Devices                             number_value        0
# PNC Arena Rental                                   number_value        0
# PNC Bank Arts Center                               number_value        0
# PNC Music Pavilion- Charlotte (Formally Verizon... number_value        0
# PNC Rental Return - 10 Units & Printers, 2 Sets... number_value        0
# Park Place Seasonal Return                         number_value        0
# Park Place Swap                                    number_value        0
# Penn State                                         number_value       20
# Penn State Charger Return                          number_value        0
# Penn State Test Drive                              number_value        0
# Philly Met Swap                                    number_value        0
# Preferred Parking                                  number_value       40
# Preferred Parking - 40 Units & Printers            number_value        0
# Preferred Parking Chargers                         number_value        0
# Rangers Rental Return                              number_value        0
# Rose Quarter Full Device Swap                      number_value        0
# Rose Quarter Return                                number_value        0
# Ruoff Home Mortgage Music Center                   number_value        0
# Rutgers                                            number_value       25
# SAP Center Device Swap                             number_value        0
# SAP Center Printer Swap                            number_value        0
# SF 49ers Rental Return                             number_value        0
# SJ Earthquakes                                     number_value        0
# SMG Jacksonville Printer Swap                      number_value        0
# SMG Jax Return                                     number_value        0
# SMG Ontario (Dan)                                  number_value        0
# SMG Ontario Full Swap                              number_value        0
# SMG Ontario Rental Return                          number_value        0
# SMU/PCA                                            number_value       12
# SP+ Atlanta Device #3 (Still in Meraki)            number_value        0
# SP+ Baltimore                                      number_value       18
# SP+ Cleveland Swap                                 number_value        0
# SP+ Columbus #1                                    number_value        0
# SP+ Columbus Sled Swap                             number_value        0
# SP+ Columbus Valet                                 number_value        0
# SP+ Columbus Valet Full Swap                       number_value        0
# SP+ Columbus iPhone Swap                           number_value        0
# SP+ DC FedEx Field                                 number_value       20
# SP+ DC FedEx Field 1 Week Rental                   number_value        0
# SP+ Fresno                                         number_value        0
# SP+ Phoenix Full Swap                              number_value        0
# SP+ Phoenix Swap                                   number_value        0
# SP+ Phoenix Westgate                               number_value        0
# SP+ SLC Swap                                       number_value        0
# SP+ Tulsa                                          number_value        0
# SP+ Vegas Rental                                   number_value        0
# SP+ Vegas Rental Return                            number_value        0
# SP+ Vegas Tropicana                                number_value        0
# SP+ Vegas Weekend Rental                           number_value        0
# Sacramento River Cats                              number_value        5
# San Diego Padres                                   number_value        0
# Saratoga Performing Arts Center                    number_value        0
# Shoreline Amphitheatre                             number_value        0
# Sloan Park Return - 20 Units and Printers          number_value        0
# Sloan Park Returns                                 number_value        0
# South Dakota State                                 number_value        0
# South Dakota State - 15 Units & Printers           number_value        0
# TCU - 14 Units & Printers                          number_value        0
# Taxslayer Equipment Refresh Swap                   number_value        0
# Texas Rangers                                      number_value       25
# The Car Park                                       number_value       10
# The Gorge Amphitheatre                             number_value        0
# Toyota Amphitheatre (Sacramento)                   number_value        0
# UCLA                                               number_value       40
# UCLA Return - 30                                   number_value        0
# UNC                                                number_value      NaN
# UNT                                                number_value        0
# UNT - 12 Units & Printers                          number_value        0
# US Military Academy (West Point/ARMY)              number_value       60
# USC Foundations Full Swap                          number_value        0
# USC Foundations Return                             number_value        0
# USC Rental                                         number_value        0
# USCali                                             number_value      NaN
# USCali - 20 Units & Printers                       number_value        0
# USCali Swap Return - 4 Units                       number_value        0
# UT Austin Full Swap                                number_value        0
# University of Arizona                              number_value        0
# University of IA Scan Only Device                  number_value        0
# University of Illinois                             number_value        0
# University of Iowa                                 number_value      NaN
# University of Washington                           number_value       40
# Usana Amphitheater                                 number_value        0
# Utah State Parks                                   number_value        0
# Utah State Parks Swap                              number_value        0
# Veterans United Home Loans Amphitheater @ Virgi... number_value        0
# White River Amphitheatre                           number_value        0
# Wolf Creek Amphitheatre                            number_value        0
# Wolf Creek Return                                  number_value        0
# XFINITY Theater (formally Comcast)                 number_value        0
# Xfinity Center (formally Comcast)                  number_value        0
# Xfinity Theatre Carrier Swap                       number_value        0
# Xfinity Theatre Rental                             number_value        0
#
# carrier                                                            ShipDate  \
# Location
# 49ers                                              number_value       02/14
# Ak-Chin Pavilion Pavilion                          number_value    09/26/19
# Alameda County Fairgrounds Seasonal Return         number_value       10/07
# Aloha Stadium Test Drive Return                    number_value           0
# Alpine Valley Music Theatre                        number_value    09/16/19
# Ameris Bank Amphitheater @ Encore Park             number_value    10/20/19
# Angels Weekend Rental                              number_value           0
# Arizona State - 15 Units & Printers                number_value           0
# Arizona State University                           number_value  03/09/2020
# Asana Tutorial                                     number_value           0
# Ascend Amphitheater                                number_value    10/25/19
# BB&T Pavilion                                      number_value    11/24/19
# BBT Center Phones                                  number_value           0
# BBT Center Phones in Meraki                        number_value           0
# Bank of New Hampshire Pavilion                     number_value     9/21/19
# Bayfront Park Amphitheater                         number_value     11/3/19
# Baylor University                                  number_value       12/09
# Bear Mountain Swap                                 number_value           0
# Blossom Music Center                               number_value     9/27/19
# Brewers                                            number_value       11/01
# Broncos Carrier Swap                               number_value           0
# Broncos Return                                     number_value           0
# CNG Rental                                         number_value       08/30
# CNG Rental Return                                  number_value           0
# COTA                                               number_value       11/11
# COTA Device Swap                                   number_value           0
# CU Boulder                                         number_value  01/07/2020
# CU Boulder - 23 Units & Printers                   number_value           0
# CU Boulder iPhone Swap                             number_value           0
# CUBS Missing Units                                 number_value           0
# Cal Berkeley                                       number_value         NaN
# Cal poly Swap                                      number_value           0
# Cellairis Amphitheater @ Lakewood                  number_value     10/7/19
# Charlotte Metro Credit Union Amphitheatre          number_value    10/16/19
# Chicago Cubs                                       number_value       10/07
# Chicago White Sox                                  number_value       10/07
# Cleveland Swap                                     number_value           0
# Coastal Credit Union Music Park @ Walnut Creek     number_value    10/19/19
# Colorado Rockies                                   number_value       10/07
# Concord Pavilion                                   number_value    10/19/19
# Coral Sky Amphitheatre                             number_value       12/20
# Coral Sky Rental                                   number_value       12/20
# Coral Sky Rental Return                            number_value           0
# Cornerstone Seasonal Return                        number_value       11/07
# Cubs Rental                                        number_value    01/07/20
# Darien Lake Performing Arts Center                 number_value     9/22/19
# Denver Broncos                                     number_value  02/07/2020
# Denver Broncos - 30 Units & Printers               number_value           0
# Dos XX Pavilion                                    number_value    11/16/19
# FITT                                               number_value  04/22/2020
# Farm Bureau Insurance Lawn @ White River State ... number_value      9/5/19
# FedEx Field Rental                                 number_value    01/14/20
# Five Point Amphitheater                            number_value    11/02/19
# Florida State Test Drive Return                    number_value           0
# Ford Amphitheatre @ Coney Island Boardwalk         number_value       10/23
# Frisco Rough Riders Baseball Return                number_value   9/07/2020
# GA Tech                                            number_value       12/09
# GA Tech/Lanier - 42 Units & Printers               number_value           0
# Georgia Southern                                   number_value       12/09
# Gillette/Patriots                                  number_value  02/14/2020
# Glen Helen Amphitheater                            number_value     9/28/19
# Greek Theater                                      number_value  11/07/2020
# Hollywood Bowl                                     number_value       11/14
# Hollywood Casino Amp - Chicago                     number_value    10/12/19
# Hollywood Casino Amp - St. Louis                   number_value    10/11/19
# Huntington Bank Pavilion at Northerly Island       number_value     9/27/19
# Interstate MN                                      number_value  02/07/2020
# Interstate Test Drive Return                       number_value           0
# Interstate WI                                      number_value        9/07
# Iowa State University                              number_value       12/09
# Iowa test drive                                    number_value           0
# Isleta Amphitheater                                number_value    09/27/19
# Jiffy Lube Live                                    number_value    10/19/19
# Joe's Auto Park Device Swap                        number_value           0
# Joe's Auto Swap Return - 4 Units                   number_value           0
# Kaboo Del Mar                                      number_value    09/24/19
# KeyBank Pavilion                                   number_value     9/28/19
# Kroenke Equipment Swap                             number_value        6/28
# Kroenke Week Rental                                number_value           0
# LA Angels Rental                                   number_value    01/20/20
# LA Angels Rental Return                            number_value           0
# LAFC Suitcase Return                               number_value           0
# LSU                                                number_value       12/09
# LSU - 75 Units & Printers                          number_value           0
# LSU Baseball Return                                number_value        7/07
# Lakeview Amphitheater                              number_value     9/14/19
# Lanier Orlando Swap                                number_value           0
# Las Vegas NYE REEF Parking Rental                  number_value    01/13/20
# Levi's Rental Return                               number_value           0
# MUFC Seasonal Return                               number_value       11/07
# Mann Center                                        number_value       10/07
# Mclaurin Baseball Return                           number_value       10/02
# Mclaurin Device Swap                               number_value           0
# Mid-Florida Credit Union Amphitheatre              number_value    12/21/19
# Mississippi State                                  number_value       12/09
# Mississippi State Return                           number_value           0
# Mississippi State University                       number_value  06/07/2020
# Mississippi State University - 63 Units & 13 Pr... number_value           0
# Mississippi State University Baseball Return       number_value           0
# Montage Mountain (formerly Toyota)                 number_value     9/26/19
# NYRA Swap Part 1                                   number_value           0
# NYRA Swap Part 2                                   number_value           0
# NYSP Green Lakes                                   number_value  01/07/2020
# NYSP Jones Beach                                   number_value  01/07/2020
# NYSP Robert Moses                                  number_value  01/07/2020
# NYSP Sunken Meadow                                 number_value  01/07/2020
# Newpoint iPhone Swap                               number_value           0
# North Island Credit Union Amphitheatre             number_value    11/18/19
# Notre Dame                                         number_value       12/09
# Notre Dame - 40 Units & Printers                   number_value           0
# Oak Mountain Amphitheater                          number_value     11/1/19
# Oakland A's Return                                 number_value           0
# Oklahoma State                                     number_value       12/09
# Oklahoma State - 30 Units                          number_value           0
# P.N.C. Bank Arts Center - 5 units                  number_value     9/14/19
# P.N.C. Bank Arts Center - 6 units                  number_value    12/27/19
# PGA Return- 20 Devices                             number_value           0
# PNC Arena Rental                                   number_value           0
# PNC Bank Arts Center                               number_value       08/12
# PNC Music Pavilion- Charlotte (Formally Verizon... number_value    10/18/19
# PNC Rental Return - 10 Units & Printers, 2 Sets... number_value           0
# Park Place Seasonal Return                         number_value        9/22
# Park Place Swap                                    number_value           0
# Penn State                                         number_value  01/07/2020
# Penn State Charger Return                          number_value           0
# Penn State Test Drive                              number_value       10/07
# Philly Met Swap                                    number_value           0
# Preferred Parking                                  number_value  02/07/2020
# Preferred Parking - 40 Units & Printers            number_value           0
# Preferred Parking Chargers                         number_value           0
# Rangers Rental Return                              number_value           0
# Rose Quarter Full Device Swap                      number_value           0
# Rose Quarter Return                                number_value           0
# Ruoff Home Mortgage Music Center                   number_value    10/18/19
# Rutgers                                            number_value  03/10/2020
# SAP Center Device Swap                             number_value           0
# SAP Center Printer Swap                            number_value           0
# SF 49ers Rental Return                             number_value           0
# SJ Earthquakes                                     number_value  01/07/2020
# SMG Jacksonville Printer Swap                      number_value           0
# SMG Jax Return                                     number_value           0
# SMG Ontario (Dan)                                  number_value           0
# SMG Ontario Full Swap                              number_value           0
# SMG Ontario Rental Return                          number_value        7/05
# SMU/PCA                                            number_value  01/07/2020
# SP+ Atlanta Device #3 (Still in Meraki)            number_value        6/19
# SP+ Baltimore                                      number_value  01/07/2020
# SP+ Cleveland Swap                                 number_value           0
# SP+ Columbus #1                                    number_value        6/21
# SP+ Columbus Sled Swap                             number_value        6/21
# SP+ Columbus Valet                                 number_value           0
# SP+ Columbus Valet Full Swap                       number_value           0
# SP+ Columbus iPhone Swap                           number_value           0
# SP+ DC FedEx Field                                 number_value  01/07/2020
# SP+ DC FedEx Field 1 Week Rental                   number_value       11/25
# SP+ Fresno                                         number_value           0
# SP+ Phoenix Full Swap                              number_value           0
# SP+ Phoenix Swap                                   number_value        6/21
# SP+ Phoenix Westgate                               number_value           0
# SP+ SLC Swap                                       number_value           0
# SP+ Tulsa                                          number_value         NaN
# SP+ Vegas Rental                                   number_value    09/23/19
# SP+ Vegas Rental Return                            number_value        7/01
# SP+ Vegas Tropicana                                number_value       10/23
# SP+ Vegas Weekend Rental                           number_value           0
# Sacramento River Cats                              number_value  03/01/2020
# San Diego Padres                                   number_value       10/07
# Saratoga Performing Arts Center                    number_value     9/21/19
# Shoreline Amphitheatre                             number_value    10/18/19
# Sloan Park Return - 20 Units and Printers          number_value           0
# Sloan Park Returns                                 number_value           0
# South Dakota State                                 number_value       12/09
# South Dakota State - 15 Units & Printers           number_value           0
# TCU - 14 Units & Printers                          number_value           0
# Taxslayer Equipment Refresh Swap                   number_value        6/19
# Texas Rangers                                      number_value           0
# The Car Park                                       number_value  05/07/2020
# The Gorge Amphitheatre                             number_value    10/12/19
# Toyota Amphitheatre (Sacramento)                   number_value    11/04/19
# UCLA                                               number_value  04/07/2020
# UCLA Return - 30                                   number_value           0
# UNC                                                number_value  04/07/2020
# UNT                                                number_value       12/09
# UNT - 12 Units & Printers                          number_value           0
# US Military Academy (West Point/ARMY)              number_value  01/09/2020
# USC Foundations Full Swap                          number_value           0
# USC Foundations Return                             number_value           0
# USC Rental                                         number_value           0
# USCali                                             number_value  02/07/2020
# USCali - 20 Units & Printers                       number_value           0
# USCali Swap Return - 4 Units                       number_value           0
# UT Austin Full Swap                                number_value           0
# University of Arizona                              number_value       12/09
# University of IA Scan Only Device                  number_value       10/01
# University of Illinois                             number_value       12/09
# University of Iowa                                 number_value  03/07/2020
# University of Washington                           number_value    12/09/19
# Usana Amphitheater                                 number_value    10/23/19
# Utah State Parks                                   number_value           0
# Utah State Parks Swap                              number_value        6/20
# Veterans United Home Loans Amphitheater @ Virgi... number_value    10/25/19
# White River Amphitheatre                           number_value     10/4/19
# Wolf Creek Amphitheatre                            number_value           0
# Wolf Creek Return                                  number_value           0
# XFINITY Theater (formally Comcast)                 number_value    10/18/19
# Xfinity Center (formally Comcast)                  number_value     9/27/19
# Xfinity Theatre Carrier Swap                       number_value        6/15
# Xfinity Theatre Rental                             number_value       12/24
#
# carrier                                                         Verifone Chargers  \
# Location
# 49ers                                              number_value                 0
# Ak-Chin Pavilion Pavilion                          number_value                 0
# Alameda County Fairgrounds Seasonal Return         number_value                 0
# Aloha Stadium Test Drive Return                    number_value                 0
# Alpine Valley Music Theatre                        number_value                 0
# Ameris Bank Amphitheater @ Encore Park             number_value                 0
# Angels Weekend Rental                              number_value                 0
# Arizona State - 15 Units & Printers                number_value                 0
# Arizona State University                           number_value                 5
# Asana Tutorial                                     number_value                 0
# Ascend Amphitheater                                number_value                 0
# BB&T Pavilion                                      number_value                 0
# BBT Center Phones                                  number_value                 0
# BBT Center Phones in Meraki                        number_value                 0
# Bank of New Hampshire Pavilion                     number_value                 0
# Bayfront Park Amphitheater                         number_value                 0
# Baylor University                                  number_value                 0
# Bear Mountain Swap                                 number_value                 0
# Blossom Music Center                               number_value                 0
# Brewers                                            number_value                 0
# Broncos Carrier Swap                               number_value                 0
# Broncos Return                                     number_value                 0
# CNG Rental                                         number_value                 0
# CNG Rental Return                                  number_value                 0
# COTA                                               number_value                 0
# COTA Device Swap                                   number_value                 0
# CU Boulder                                         number_value                 0
# CU Boulder - 23 Units & Printers                   number_value                 0
# CU Boulder iPhone Swap                             number_value                 0
# CUBS Missing Units                                 number_value                 0
# Cal Berkeley                                       number_value                 0
# Cal poly Swap                                      number_value                 0
# Cellairis Amphitheater @ Lakewood                  number_value                 0
# Charlotte Metro Credit Union Amphitheatre          number_value                 0
# Chicago Cubs                                       number_value                 0
# Chicago White Sox                                  number_value                 0
# Cleveland Swap                                     number_value                 0
# Coastal Credit Union Music Park @ Walnut Creek     number_value                 0
# Colorado Rockies                                   number_value                 0
# Concord Pavilion                                   number_value                 0
# Coral Sky Amphitheatre                             number_value                 0
# Coral Sky Rental                                   number_value                 0
# Coral Sky Rental Return                            number_value                 0
# Cornerstone Seasonal Return                        number_value                 0
# Cubs Rental                                        number_value                 0
# Darien Lake Performing Arts Center                 number_value                 0
# Denver Broncos                                     number_value                 6
# Denver Broncos - 30 Units & Printers               number_value                 0
# Dos XX Pavilion                                    number_value                 0
# FITT                                               number_value                 1
# Farm Bureau Insurance Lawn @ White River State ... number_value                 0
# FedEx Field Rental                                 number_value                 3
# Five Point Amphitheater                            number_value                 0
# Florida State Test Drive Return                    number_value                 0
# Ford Amphitheatre @ Coney Island Boardwalk         number_value                 0
# Frisco Rough Riders Baseball Return                number_value                 2
# GA Tech                                            number_value                 0
# GA Tech/Lanier - 42 Units & Printers               number_value                 0
# Georgia Southern                                   number_value                 0
# Gillette/Patriots                                  number_value                 8
# Glen Helen Amphitheater                            number_value                 0
# Greek Theater                                      number_value                 3
# Hollywood Bowl                                     number_value                 0
# Hollywood Casino Amp - Chicago                     number_value                 0
# Hollywood Casino Amp - St. Louis                   number_value                 0
# Huntington Bank Pavilion at Northerly Island       number_value                 0
# Interstate MN                                      number_value               NaN
# Interstate Test Drive Return                       number_value                 0
# Interstate WI                                      number_value                 0
# Iowa State University                              number_value                 0
# Iowa test drive                                    number_value                 0
# Isleta Amphitheater                                number_value                 0
# Jiffy Lube Live                                    number_value                 0
# Joe's Auto Park Device Swap                        number_value                 0
# Joe's Auto Swap Return - 4 Units                   number_value                 0
# Kaboo Del Mar                                      number_value                 0
# KeyBank Pavilion                                   number_value                 0
# Kroenke Equipment Swap                             number_value                 0
# Kroenke Week Rental                                number_value                 0
# LA Angels Rental                                   number_value               NaN
# LA Angels Rental Return                            number_value                 0
# LAFC Suitcase Return                               number_value                 0
# LSU                                                number_value                 0
# LSU - 75 Units & Printers                          number_value                 0
# LSU Baseball Return                                number_value                 0
# Lakeview Amphitheater                              number_value                 0
# Lanier Orlando Swap                                number_value                 0
# Las Vegas NYE REEF Parking Rental                  number_value                 1
# Levi's Rental Return                               number_value                 0
# MUFC Seasonal Return                               number_value                 0
# Mann Center                                        number_value                 0
# Mclaurin Baseball Return                           number_value                 0
# Mclaurin Device Swap                               number_value                 0
# Mid-Florida Credit Union Amphitheatre              number_value                 0
# Mississippi State                                  number_value                 0
# Mississippi State Return                           number_value                 0
# Mississippi State University                       number_value                 3
# Mississippi State University - 63 Units & 13 Pr... number_value                 0
# Mississippi State University Baseball Return       number_value                 0
# Montage Mountain (formerly Toyota)                 number_value                 0
# NYRA Swap Part 1                                   number_value                 0
# NYRA Swap Part 2                                   number_value                 0
# NYSP Green Lakes                                   number_value                 0
# NYSP Jones Beach                                   number_value                 0
# NYSP Robert Moses                                  number_value                 0
# NYSP Sunken Meadow                                 number_value                 0
# Newpoint iPhone Swap                               number_value                 0
# North Island Credit Union Amphitheatre             number_value                 0
# Notre Dame                                         number_value                 0
# Notre Dame - 40 Units & Printers                   number_value                 0
# Oak Mountain Amphitheater                          number_value                 0
# Oakland A's Return                                 number_value                 0
# Oklahoma State                                     number_value                 0
# Oklahoma State - 30 Units                          number_value                 0
# P.N.C. Bank Arts Center - 5 units                  number_value                 0
# P.N.C. Bank Arts Center - 6 units                  number_value                 0
# PGA Return- 20 Devices                             number_value                 0
# PNC Arena Rental                                   number_value                 0
# PNC Bank Arts Center                               number_value                 0
# PNC Music Pavilion- Charlotte (Formally Verizon... number_value                 0
# PNC Rental Return - 10 Units & Printers, 2 Sets... number_value                 0
# Park Place Seasonal Return                         number_value                 0
# Park Place Swap                                    number_value                 0
# Penn State                                         number_value                 1
# Penn State Charger Return                          number_value                 0
# Penn State Test Drive                              number_value                 0
# Philly Met Swap                                    number_value                 0
# Preferred Parking                                  number_value                 8
# Preferred Parking - 40 Units & Printers            number_value                 0
# Preferred Parking Chargers                         number_value                 0
# Rangers Rental Return                              number_value                 0
# Rose Quarter Full Device Swap                      number_value                 0
# Rose Quarter Return                                number_value                 0
# Ruoff Home Mortgage Music Center                   number_value                 0
# Rutgers                                            number_value                 5
# SAP Center Device Swap                             number_value                 0
# SAP Center Printer Swap                            number_value                 0
# SF 49ers Rental Return                             number_value                 0
# SJ Earthquakes                                     number_value                 0
# SMG Jacksonville Printer Swap                      number_value                 0
# SMG Jax Return                                     number_value                 0
# SMG Ontario (Dan)                                  number_value                 0
# SMG Ontario Full Swap                              number_value                 0
# SMG Ontario Rental Return                          number_value                 0
# SMU/PCA                                            number_value                 3
# SP+ Atlanta Device #3 (Still in Meraki)            number_value                 0
# SP+ Baltimore                                      number_value                 4
# SP+ Cleveland Swap                                 number_value                 0
# SP+ Columbus #1                                    number_value                 0
# SP+ Columbus Sled Swap                             number_value                 0
# SP+ Columbus Valet                                 number_value                 0
# SP+ Columbus Valet Full Swap                       number_value                 0
# SP+ Columbus iPhone Swap                           number_value                 0
# SP+ DC FedEx Field                                 number_value                 4
# SP+ DC FedEx Field 1 Week Rental                   number_value                 0
# SP+ Fresno                                         number_value                 0
# SP+ Phoenix Full Swap                              number_value                 0
# SP+ Phoenix Swap                                   number_value                 0
# SP+ Phoenix Westgate                               number_value                 0
# SP+ SLC Swap                                       number_value                 0
# SP+ Tulsa                                          number_value                 0
# SP+ Vegas Rental                                   number_value                 0
# SP+ Vegas Rental Return                            number_value                 0
# SP+ Vegas Tropicana                                number_value                 0
# SP+ Vegas Weekend Rental                           number_value                 0
# Sacramento River Cats                              number_value                 1
# San Diego Padres                                   number_value                 0
# Saratoga Performing Arts Center                    number_value                 0
# Shoreline Amphitheatre                             number_value                 0
# Sloan Park Return - 20 Units and Printers          number_value                 0
# Sloan Park Returns                                 number_value                 0
# South Dakota State                                 number_value                 0
# South Dakota State - 15 Units & Printers           number_value                 0
# TCU - 14 Units & Printers                          number_value                 0
# Taxslayer Equipment Refresh Swap                   number_value                 0
# Texas Rangers                                      number_value                 5
# The Car Park                                       number_value                 5
# The Gorge Amphitheatre                             number_value                 0
# Toyota Amphitheatre (Sacramento)                   number_value                 0
# ...
# Wolf Creek Return                                  number_value              0
# XFINITY Theater (formally Comcast)                 number_value              0
# Xfinity Center (formally Comcast)                  number_value              0
# Xfinity Theatre Carrier Swap                       number_value              0
# Xfinity Theatre Rental                             number_value              0
#
# carrier                                                         iPhones
# Location
# 49ers                                              number_value       0
# Ak-Chin Pavilion Pavilion                          number_value       0
# Alameda County Fairgrounds Seasonal Return         number_value       0
# Aloha Stadium Test Drive Return                    number_value       0
# Alpine Valley Music Theatre                        number_value       0
# Ameris Bank Amphitheater @ Encore Park             number_value       0
# Angels Weekend Rental                              number_value       0
# Arizona State - 15 Units & Printers                number_value       0
# Arizona State University                           number_value      25
# Asana Tutorial                                     number_value       0
# Ascend Amphitheater                                number_value       0
# BB&T Pavilion                                      number_value       0
# BBT Center Phones                                  number_value       0
# BBT Center Phones in Meraki                        number_value       0
# Bank of New Hampshire Pavilion                     number_value       0
# Bayfront Park Amphitheater                         number_value       0
# Baylor University                                  number_value       0
# Bear Mountain Swap                                 number_value       0
# Blossom Music Center                               number_value       0
# Brewers                                            number_value       0
# Broncos Carrier Swap                               number_value       0
# Broncos Return                                     number_value       0
# CNG Rental                                         number_value       0
# CNG Rental Return                                  number_value       0
# COTA                                               number_value       0
# COTA Device Swap                                   number_value       0
# CU Boulder                                         number_value       0
# CU Boulder - 23 Units & Printers                   number_value       0
# CU Boulder iPhone Swap                             number_value       0
# CUBS Missing Units                                 number_value       0
# Cal Berkeley                                       number_value       0
# Cal poly Swap                                      number_value       0
# Cellairis Amphitheater @ Lakewood                  number_value       0
# Charlotte Metro Credit Union Amphitheatre          number_value       0
# Chicago Cubs                                       number_value       0
# Chicago White Sox                                  number_value       0
# Cleveland Swap                                     number_value       0
# Coastal Credit Union Music Park @ Walnut Creek     number_value       0
# Colorado Rockies                                   number_value       0
# Concord Pavilion                                   number_value       0
# Coral Sky Amphitheatre                             number_value       0
# Coral Sky Rental                                   number_value       0
# Coral Sky Rental Return                            number_value       0
# Cornerstone Seasonal Return                        number_value       0
# Cubs Rental                                        number_value       2
# Darien Lake Performing Arts Center                 number_value       0
# Denver Broncos                                     number_value      30
# Denver Broncos - 30 Units & Printers               number_value       0
# Dos XX Pavilion                                    number_value       0
# FITT                                               number_value       5
# Farm Bureau Insurance Lawn @ White River State ... number_value       0
# FedEx Field Rental                                 number_value      15
# Five Point Amphitheater                            number_value       0
# Florida State Test Drive Return                    number_value       0
# Ford Amphitheatre @ Coney Island Boardwalk         number_value       0
# Frisco Rough Riders Baseball Return                number_value       8
# GA Tech                                            number_value       0
# GA Tech/Lanier - 42 Units & Printers               number_value       0
# Georgia Southern                                   number_value       0
# Gillette/Patriots                                  number_value      39
# Glen Helen Amphitheater                            number_value       0
# Greek Theater                                      number_value      15
# Hollywood Bowl                                     number_value       0
# Hollywood Casino Amp - Chicago                     number_value       0
# Hollywood Casino Amp - St. Louis                   number_value       0
# Huntington Bank Pavilion at Northerly Island       number_value       0
# Interstate MN                                      number_value     NaN
# Interstate Test Drive Return                       number_value       0
# Interstate WI                                      number_value       0
# Iowa State University                              number_value       0
# Iowa test drive                                    number_value       0
# Isleta Amphitheater                                number_value       0
# Jiffy Lube Live                                    number_value       0
# Joe's Auto Park Device Swap                        number_value       0
# Joe's Auto Swap Return - 4 Units                   number_value       0
# Kaboo Del Mar                                      number_value       0
# KeyBank Pavilion                                   number_value       0
# Kroenke Equipment Swap                             number_value       0
# Kroenke Week Rental                                number_value       0
# LA Angels Rental                                   number_value     NaN
# LA Angels Rental Return                            number_value       0
# LAFC Suitcase Return                               number_value       0
# LSU                                                number_value       0
# LSU - 75 Units & Printers                          number_value       0
# LSU Baseball Return                                number_value       0
# Lakeview Amphitheater                              number_value       0
# Lanier Orlando Swap                                number_value       0
# Las Vegas NYE REEF Parking Rental                  number_value       6
# Levi's Rental Return                               number_value       0
# MUFC Seasonal Return                               number_value       0
# Mann Center                                        number_value       0
# Mclaurin Baseball Return                           number_value       0
# Mclaurin Device Swap                               number_value       0
# Mid-Florida Credit Union Amphitheatre              number_value       0
# Mississippi State                                  number_value       0
# Mississippi State Return                           number_value       0
# Mississippi State University                       number_value      13
# Mississippi State University - 63 Units & 13 Pr... number_value       0
# Mississippi State University Baseball Return       number_value       0
# Montage Mountain (formerly Toyota)                 number_value       0
# NYRA Swap Part 1                                   number_value       0
# NYRA Swap Part 2                                   number_value       0
# NYSP Green Lakes                                   number_value       0
# NYSP Jones Beach                                   number_value       0
# NYSP Robert Moses                                  number_value       0
# NYSP Sunken Meadow                                 number_value       0
# Newpoint iPhone Swap                               number_value       0
# North Island Credit Union Amphitheatre             number_value       0
# Notre Dame                                         number_value       0
# Notre Dame - 40 Units & Printers                   number_value       0
# Oak Mountain Amphitheater                          number_value       0
# Oakland A's Return                                 number_value       0
# Oklahoma State                                     number_value       0
# Oklahoma State - 30 Units                          number_value       0
# P.N.C. Bank Arts Center - 5 units                  number_value       0
# P.N.C. Bank Arts Center - 6 units                  number_value       0
# PGA Return- 20 Devices                             number_value       0
# PNC Arena Rental                                   number_value       0
# PNC Bank Arts Center                               number_value       0
# PNC Music Pavilion- Charlotte (Formally Verizon... number_value       0
# PNC Rental Return - 10 Units & Printers, 2 Sets... number_value       0
# Park Place Seasonal Return                         number_value       0
# Park Place Swap                                    number_value       0
# Penn State                                         number_value      20
# Penn State Charger Return                          number_value       0
# Penn State Test Drive                              number_value       0
# Philly Met Swap                                    number_value       0
# Preferred Parking                                  number_value      40
# Preferred Parking - 40 Units & Printers            number_value       0
# Preferred Parking Chargers                         number_value       0
# Rangers Rental Return                              number_value       0
# Rose Quarter Full Device Swap                      number_value       0
# Rose Quarter Return                                number_value       0
# Ruoff Home Mortgage Music Center                   number_value       0
# Rutgers                                            number_value      25
# SAP Center Device Swap                             number_value       0
# SAP Center Printer Swap                            number_value       0
# SF 49ers Rental Return                             number_value       0
# SJ Earthquakes                                     number_value       0
# SMG Jacksonville Printer Swap                      number_value       0
# SMG Jax Return                                     number_value       0
# SMG Ontario (Dan)                                  number_value       0
# SMG Ontario Full Swap                              number_value       0
# SMG Ontario Rental Return                          number_value       0
# SMU/PCA                                            number_value      12
# SP+ Atlanta Device #3 (Still in Meraki)            number_value       0
# SP+ Baltimore                                      number_value      18
# SP+ Cleveland Swap                                 number_value       0
# SP+ Columbus #1                                    number_value       0
# SP+ Columbus Sled Swap                             number_value       0
# SP+ Columbus Valet                                 number_value       0
# SP+ Columbus Valet Full Swap                       number_value       0
# SP+ Columbus iPhone Swap                           number_value       0
# SP+ DC FedEx Field                                 number_value      20
# SP+ DC FedEx Field 1 Week Rental                   number_value       0
# SP+ Fresno                                         number_value       0
# SP+ Phoenix Full Swap                              number_value       0
# SP+ Phoenix Swap                                   number_value       0
# SP+ Phoenix Westgate                               number_value       0
# SP+ SLC Swap                                       number_value       0
# SP+ Tulsa                                          number_value       0
# SP+ Vegas Rental                                   number_value       0
# SP+ Vegas Rental Return                            number_value       0
# SP+ Vegas Tropicana                                number_value       0
# SP+ Vegas Weekend Rental                           number_value       0
# Sacramento River Cats                              number_value       5
# San Diego Padres                                   number_value       0
# Saratoga Performing Arts Center                    number_value       0
# Shoreline Amphitheatre                             number_value       0
# Sloan Park Return - 20 Units and Printers          number_value       0
# Sloan Park Returns                                 number_value       0
# South Dakota State                                 number_value       0
# South Dakota State - 15 Units & Printers           number_value       0
# TCU - 14 Units & Printers                          number_value       0
# Taxslayer Equipment Refresh Swap                   number_value       0
# Texas Rangers                                      number_value      25
# The Car Park                                       number_value      10
# The Gorge Amphitheatre                             number_value       0
# Toyota Amphitheatre (Sacramento)                   number_value       0
# UCLA                                               number_value      40
# UCLA Return - 30                                   number_value       0
# UNC                                                number_value     NaN
# UNT                                                number_value       0
# UNT - 12 Units & Printers                          number_value       0
# US Military Academy (West Point/ARMY)              number_value      60
# USC Foundations Full Swap                          number_value       0
# USC Foundations Return                             number_value       0
# USC Rental                                         number_value       0
# USCali                                             number_value     NaN
# USCali - 20 Units & Printers                       number_value       0
# USCali Swap Return - 4 Units                       number_value       0
# UT Austin Full Swap                                number_value       0
# University of Arizona                              number_value       0
# University of IA Scan Only Device                  number_value       0
# University of Illinois                             number_value       0
# University of Iowa                                 number_value     NaN
# University of Washington                           number_value      40
# Usana Amphitheater                                 number_value       0
# Utah State Parks                                   number_value       0
# Utah State Parks Swap                              number_value       0
# Veterans United Home Loans Amphitheater @ Virgi... number_value       0
# White River Amphitheatre                           number_value       0
# Wolf Creek Amphitheatre                            number_value       0
# Wolf Creek Return                                  number_value       0
# XFINITY Theater (formally Comcast)                 number_value       0
# Xfinity Center (formally Comcast)                  number_value       0
# Xfinity Theatre Carrier Swap                       number_value       0
# Xfinity Theatre Rental                             number_value       0
